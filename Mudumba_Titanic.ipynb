# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
titanic_df=pd.read_csv('train.csv')

# %%
titanic_df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
titanic_df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
titanic_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.6+ KB

# %% [markdown]
# All good data analysis projects begin with trying to answer questions
# First some basic questions:
#
#     1.) Who were the passengers on the Titanic? (Ages,Gender,Class,..etc)
#     2.) What deck were the passengers on and how does that relate to their class?
#     3.) Where did the passengers come from?
#     4.) Who was alone and who was with family?
#
# Then we'll dig deeper, with a broader question:
#
#     5.) What factors helped someone survive the sinking?

# %%
sns.catplot(x='Sex', kind='count',data=titanic_df)

# %%
sns.catplot(x='Sex', hue='Pclass', data= titanic_df, kind='count')

# %%
sns.catplot(x='Pclass', hue='Sex', data= titanic_df, kind='count')

# %%
def male_female_child(passenger):
    age, sex = passenger
    
    if age< 16:
        return 'child'
    else:
        return sex

# %%
titanic_df['Person']=titanic_df[['Age', 'Sex']].apply(male_female_child, axis=1)

# %%
titanic_df[titanic_df.Age < 16]
# Out:
#      PassengerId  Survived  Pclass  \
# 7              8         0       3
# 9             10         1       2
# 10            11         1       3
# 14            15         0       3
# 16            17         0       3
# 22            23         1       3
# 24            25         0       3
# 39            40         1       3
# 43            44         1       2
# 50            51         0       3
# 58            59         1       2
# 59            60         0       3
# 63            64         0       3
# 78            79         1       2
# 111          112         0       3
# 119          120         0       3
# 125          126         1       3
# 147          148         0       3
# 164          165         0       3
# 165          166         1       3
# 171          172         0       3
# 172          173         1       3
# 182          183         0       3
# 183          184         1       2
# 184          185         1       3
# ...

# %%
sns.catplot(x='Pclass', hue='Person', data= titanic_df, kind='count')

# %%
titanic_df['Age'].hist(bins=70)

# %%
titanic_df['Age'].mean()
# Out:
# 29.69911764705882

# %%
titanic_df['Person'].value_counts()
# Out:
# male      537
# female    271
# child      83
# Name: Person, dtype: int64

# %%
fig= sns.FacetGrid(titanic_df, hue='Sex', aspect=4)
fig.map(sns.kdeplot, 'Age', shade= True)

oldest=titanic_df['Age'].max()

fig.set(xlim=(0, oldest))

fig.add_legend()

# %%
fig= sns.FacetGrid(titanic_df, hue='Person', aspect=4)
fig.map(sns.kdeplot, 'Age', shade= True)

oldest=titanic_df['Age'].max()

fig.set(xlim=(0, oldest))

fig.add_legend()

# %%
fig= sns.FacetGrid(titanic_df, hue='Pclass', aspect=4)
fig.map(sns.kdeplot, 'Age', shade= True)

oldest=titanic_df['Age'].max()

fig.set(xlim=(0, oldest))

fig.add_legend()

# %%
# Question 2

# %%
titanic_df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  person  Person
# 0      0         A/5 21171   7.2500   NaN        S    male    male
# 1      0          PC 17599  71.2833   C85        C  female  female
# 2      0  STON/O2. 3101282   7.9250   NaN        S  female  female
# ...

# %%
deck=titanic_df.Cabin.dropna()

# %%
deck.head()
# Out:
# 1      C85
# 3     C123
# 6      E46
# 10      G6
# 11    C103
# Name: Cabin, dtype: object

# %%
levels=[]
for level in deck:
    levels.append(level[0])

# %%
levels
# Out:
# ['C',
#  'C',
#  'E',
#  'G',
#  'C',
#  'D',
#  'A',
#  'C',
#  'B',
#  'D',
#  'B',
#  'C',
#  'B',
#  'C',
#  'F',
#  'F',
#  'C',
#  'E',
#  'A',
#  'D',
#  'D',
#  'C',
#  'B',
#  'E',
#  'D',
#  'F',
#  'D',
#  'C',
#  'B',
#  'F',
#  'C',
#  'E',
#  'B',
#  'A',
#  'C',
#  'F',
#  'A',
#  'F',
#  'B',
#  'B',
#  'G',
#  'A',
#  'D',
#  'D',
#  'C',
#  'C',
#  'C',
#  'D',
#  'G',
#  'C',
#  'B',
#  'E',
#  'B',
#  'C',
#  'C',
#  'C',
#  'D',
#  'A',
#  'B',
#  'D',
#  'C',
#  'C',
#  'B',
#  'E',
#  'C',
#  'C',
#  'E',
#  'C',
#  'B',
#  'C',
#  'E',
#  'C',
#  'D',
#  'B',
#  'C',
#  'C',
#  'C',
#  'E',
#  'T',
#  'F',
#  'C',
#  'F',
#  'C',
#  'E',
#  'D',
#  'B',
#  'E',
#  'C',
#  'B',
#  'D',
#  'G',
#  'C',
#  'E',
#  'C',
#  'E',
#  'B',
#  'C',
#  'A',
#  'C',
#  'C',
#  'C',
#  'E',
#  'D',
#  'E',
#  'E',
#  'D',
#  'A',
#  'B',
#  'C',
#  'B',
#  'C',
#  'D',
#  'C',
#  'B',
#  'C',
#  'E',
#  'D',
#  'F',
#  'B',
#  'B',
#  'C',
#  'B',
#  'B',
#  'B',
#  'C',
# ...

# %%
cabin_df=pd.DataFrame(levels)
cabin_df.columns=['Cabin']

# %%
sns.catplot('Cabin', data=cabin_df, palette='winter_d', kind='count')

# %%
cabin_df=cabin_df[cabin_df.Cabin != 'T']

# %%
sns.catplot('Cabin', data=cabin_df, palette='summer', kind='count')

# %%
#Question 3
titanic_df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  person  Person
# 0      0         A/5 21171   7.2500   NaN        S    male    male
# 1      0          PC 17599  71.2833   C85        C  female  female
# 2      0  STON/O2. 3101282   7.9250   NaN        S  female  female
# ...

# %%
sns.catplot('Embarked', data=titanic_df, hue='Pclass', kind='count', col_order=['C', 'Q', 'S'])

# %%
#Question 4
titanic_df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  person  Person
# 0      0         A/5 21171   7.2500   NaN        S    male    male
# 1      0          PC 17599  71.2833   C85        C  female  female
# 2      0  STON/O2. 3101282   7.9250   NaN        S  female  female
# ...

# %%
titanic_df['Alone']=titanic_df.SibSp + titanic_df.Parch

# %%
titanic_df['Alone']
# Out:
# 0       1
# 1       1
# 2       0
# 3       1
# 4       0
# 5       0
# 6       0
# 7       4
# 8       2
# 9       1
# 10      2
# 11      0
# 12      0
# 13      6
# 14      0
# 15      0
# 16      5
# 17      0
# 18      1
# 19      0
# 20      0
# 21      0
# 22      0
# 23      0
# 24      4
# 25      6
# 26      0
# 27      5
# 28      0
# 29      0
#        ..
# 861     1
# 862     0
# 863    10
# 864     0
# 865     0
# 866     1
# 867     0
# 868     0
# 869     2
# 870     0
# 871     2
# 872     0
# 873     0
# 874     1
# 875     0
# 876     0
# 877     0
# 878     0
# 879     1
# 880     1
# 881     0
# 882     0
# 883     0
# 884     0
# 885     5
# 886     0
# 887     0
# 888     3
# 889     0
# 890     0
# Name: Alone, Length: 891, dtype: int64

# %%
titanic_df['Alone'].loc[titanic_df['Alone']>0] = 'With Family'
titanic_df['Alone'].loc[titanic_df['Alone']==0] = 'Alone'
# Out:
# C:\Users\varun\Anaconda3\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
titanic_df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  person  Person  \
# 0      0         A/5 21171   7.2500   NaN        S    male    male
# 1      0          PC 17599  71.2833   C85        C  female  female
# 2      0  STON/O2. 3101282   7.9250   NaN        S  female  female
# ...

# %%
sns.catplot('Alone', data=titanic_df, kind='count', palette='Blues')

# %%
#Advanced Question
titanic_df['Survivor']=titanic_df.Survived.map({0:'no',1:'yes'})

sns.catplot('Survivor', data=titanic_df, palette='Set1', kind='count')

# %%
#if class has affect
sns.factorplot(x='Pclass', y='Survived', hue='Person', data=titanic_df)
# Out:
# C:\Users\varun\Anaconda3\lib\site-packages\seaborn\categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %%
#Age vs Survived
sns.lmplot('Age', 'Survived', data=titanic_df)

# %%
sns.lmplot('Age', 'Survived', hue='Pclass',palette='winter',data=titanic_df)

# %%
generation=[10,20,40,60,80]

sns.lmplot('Age', 'Survived', hue='Pclass', data=titanic_df, palette='winter', x_bins=generation)

# %%
#
sns.lmplot('Age', 'Survived', hue='Sex', data=titanic_df, palette='winter', x_bins=generation)

# %%
titanic_df['Deck']=cabin_df.Cabin

# %%
samp=titanic_df.dropna()

# %%
samp.head()
# Out:
#     PassengerId  Survived  Pclass  \
# 1             2         1       1
# 3             4         1       1
# 6             7         0       1
# 10           11         1       3
# 11           12         1       1
#
#                                                  Name     Sex   Age  SibSp  \
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                             McCarthy, Mr. Timothy J    male  54.0      0
# 10                    Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                           Bonnell, Miss. Elizabeth  female  58.0      0
#
#     Parch    Ticket     Fare Cabin Embarked  person  Person        Alone  \
# 1       0  PC 17599  71.2833   C85        C  female  female  With Family
# 3       0    113803  53.1000  C123        S  female  female  With Family
# 6       0     17463  51.8625   E46        S    male    male        Alone
# ...

# %%
#Deck had an effect on survival rate?
sns.catplot( 'Survived', kind='count',hue='Deck',data=titanic_df, palette='winter')

# %%
#What was the proportion of the persons survived based on Deck
sns.barplot('Deck', 'Survived', hue='Person', data=titanic_df, palette='summer')

# %%
#Having a family member increase the odds of surviving the crash?
titanic_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %%
sns.catplot('Survivor', data=titanic_df, hue='Alone', kind='count')
